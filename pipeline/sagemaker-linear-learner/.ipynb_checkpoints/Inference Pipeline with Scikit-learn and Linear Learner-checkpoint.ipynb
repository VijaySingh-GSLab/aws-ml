# %% [markdown]
# # Inference Pipeline with Scikit-learn and Linear Learner
# Typically a Machine Learning (ML) process consists of few steps: data gathering with various ETL jobs, pre-processing the data, featurizing the dataset by incorporating standard techniques or prior knowledge, and finally training an ML model using an algorithm.
# In many cases, when the trained model is used for processing real time or batch prediction requests, the model receives data in a format which needs to pre-processed (e.g. featurized) before it can be passed to the algorithm. In the following notebook, we will demonstrate how you can build your ML Pipeline leveraging the Sagemaker Scikit-learn container and SageMaker Linear Learner algorithm & after the model is trained, deploy the Pipeline (Data preprocessing and Lineara Learner) as an Inference Pipeline behind a single Endpoint for real time inference and for batch inferences using Amazon SageMaker Batch Transform.
#
# We will demonstrate this using the Abalone Dataset to guess the age of Abalone with physical features. The dataset is available from [UCI Machine Learning](https://archive.ics.uci.edu/ml/datasets/abalone); the aim for this task is to determine age of an Abalone (a kind of shellfish) from its physical measurements. We'll use Sagemaker's Scikit-learn container to featurize the dataset so that it can be used for training with Linear Learner.
#
# ### Table of contents
# * [Preprocessing data and training the model](#training)
#  * [Upload the data for training](#upload_data)
#  * [Create a Scikit-learn script to train with](#create_sklearn_script)
#  * [Create SageMaker Scikit Estimator](#create_sklearn_estimator)
#  * [Batch transform our training data](#preprocess_train_data)
#  * [Fit a LinearLearner Model with the preprocessed data](#training_model)
# * [Inference Pipeline with Scikit preprocessor and Linear Learner](#inference_pipeline)
#  * [Set up the inference pipeline](#pipeline_setup)
#  * [Make a request to our pipeline endpoint](#pipeline_inference_request)
#  * [Delete Endpoint](#delete_endpoint)

# %% [markdown]
# Let's first create our Sagemaker session and role, and create a S3 prefix to use for the notebook example.

# %%
import sagemaker
from sagemaker import get_execution_role

sagemaker_session = sagemaker.Session()

# Get a SageMaker-compatible role used by this Notebook Instance.
role = get_execution_role()

# S3 prefix
bucket = sagemaker_session.default_bucket()
prefix = 'Scikit-LinearLearner-pipeline-abalone-example'

# %%
bucket
# Out:
# 'sagemaker-us-east-1-120286446822'

# %% [markdown]
# # Preprocessing data and training the model <a class="anchor" id="training"></a>
# ## Downloading dataset <a class="anchor" id="download_data"></a>
# SageMaker team has downloaded the dataset from UCI and uploaded to one of the S3 buckets in our account.

# %%
# !wget --directory-prefix=./abalone_data https://s3-us-west-2.amazonaws.com/sparkml-mleap/data/abalone/abalone.csv
# Out:
# --2020-09-16 10:57:05--  https://s3-us-west-2.amazonaws.com/sparkml-mleap/data/abalone/abalone.csv
# Resolving s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)... 52.218.245.24
# Connecting to s3-us-west-2.amazonaws.com (s3-us-west-2.amazonaws.com)|52.218.245.24|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 191873 (187K) [binary/octet-stream]
# Saving to: ‘./abalone_data/abalone.csv.1’
#
# abalone.csv.1       100%[===================>] 187.38K   861KB/s    in 0.2s
#
# 2020-09-16 10:57:06 (861 KB/s) - ‘./abalone_data/abalone.csv.1’ saved [191873/191873]

# %% [markdown]
# ## Upload the data for training <a class="anchor" id="upload_data"></a>
#
# When training large models with huge amounts of data, you'll typically use big data tools, like Amazon Athena, AWS Glue, or Amazon EMR, to create your data in S3. We can use the tools provided by the SageMaker Python SDK to upload the data to a default bucket.

# %%
WORK_DIRECTORY = 'abalone_data'

train_input = sagemaker_session.upload_data(
    path='{}/{}'.format(WORK_DIRECTORY, 'abalone.csv'), 
    bucket=bucket,
    key_prefix='{}/{}'.format(prefix, 'train'))

# %% [markdown]
# ## Create a Scikit-learn script to train with <a class="anchor" id="create_sklearn_script"></a>
# To run Scikit-learn on Sagemaker `SKLearn` Estimator with a script as an entry point. The training script is very similar to a training script you might run outside of SageMaker, but you can access useful properties about the training environment through various environment variables, such as:
#
# * SM_MODEL_DIR: A string representing the path to the directory to write model artifacts to. These artifacts are uploaded to S3 for model hosting.
# * SM_OUTPUT_DIR: A string representing the filesystem path to write output artifacts to. Output artifacts may include checkpoints, graphs, and other files to save, not including model artifacts. These artifacts are compressed and uploaded to S3 to the same S3 prefix as the model artifacts.
#
# Supposing two input channels, 'train' and 'test', were used in the call to the Chainer estimator's fit() method, the following will be set, following the format SM_CHANNEL_[channel_name]:
#
# * SM_CHANNEL_TRAIN: A string representing the path to the directory containing data in the 'train' channel
# * SM_CHANNEL_TEST: Same as above, but for the 'test' channel.
#
# A typical training script loads data from the input channels, configures training with hyperparameters, trains a model, and saves a model to model_dir so that it can be hosted later. Hyperparameters are passed to your script as arguments and can be retrieved with an argparse.ArgumentParser instance. For example, the script run by this notebook:
#
# ```python
# from __future__ import print_function
#
# import time
# import sys
# from io import StringIO
# import os
# import shutil
#
# import argparse
# import csv
# import json
# import joblib
# import numpy as np
# import pandas as pd
#
# from sklearn.compose import ColumnTransformer, make_column_selector
# from sklearn.impute import SimpleImputer
# from sklearn.pipeline import make_pipeline
# from sklearn.preprocessing import Binarizer, StandardScaler, OneHotEncoder
#
# from sagemaker_containers.beta.framework import (
#     content_types, encoders, env, modules, transformer, worker)
#
# # Since we get a headerless CSV file we specify the column names here.
# feature_columns_names = [
#     'sex', # M, F, and I (infant)
#     'length', # Longest shell measurement
#     'diameter', # perpendicular to length
#     'height', # with meat in shell
#     'whole_weight', # whole abalone
#     'shucked_weight', # weight of meat
#     'viscera_weight', # gut weight (after bleeding)
#     'shell_weight'] # after being dried
#
# label_column = 'rings'
#
# feature_columns_dtype = {
#     'sex': "category",
#     'length': "float64",
#     'diameter': "float64",
#     'height': "float64",
#     'whole_weight': "float64",
#     'shucked_weight': "float64",
#     'viscera_weight': "float64",
#     'shell_weight': "float64"}
#
# label_column_dtype = {'rings': "float64"} # +1.5 gives the age in years
#
# def merge_two_dicts(x, y):
#     z = x.copy()   # start with x's keys and values
#     z.update(y)    # modifies z with y's keys and values & returns None
#     return z
#
# if __name__ == '__main__':
#
#     parser = argparse.ArgumentParser()
#
#     # Sagemaker specific arguments. Defaults are set in the environment variables.
#     parser.add_argument('--output-data-dir', type=str, default=os.environ['SM_OUTPUT_DATA_DIR'])
#     parser.add_argument('--model-dir', type=str, default=os.environ['SM_MODEL_DIR'])
#     parser.add_argument('--train', type=str, default=os.environ['SM_CHANNEL_TRAIN'])
#
#     args = parser.parse_args()
#
#     # Take the set of files and read them all into a single pandas dataframe
#     input_files = [ os.path.join(args.train, file) for file in os.listdir(args.train) ]
#     if len(input_files) == 0:
#         raise ValueError(('There are no files in {}.\n' +
#                           'This usually indicates that the channel ({}) was incorrectly specified,\n' +
#                           'the data specification in S3 was incorrectly specified or the role specified\n' +
#                           'does not have permission to access the data.').format(args.train, "train"))
#
#     raw_data = [ pd.read_csv(
#         file,
#         header=None,
#         names=feature_columns_names + [label_column],
#         dtype=merge_two_dicts(feature_columns_dtype, label_column_dtype)) for file in input_files ]
#     concat_data = pd.concat(raw_data)
#
#     # Labels should not be preprocessed. predict_fn will reinsert the labels after featurizing.
#     concat_data.drop(label_column, axis=1, inplace=True)
#
#     # This section is adapted from the scikit-learn example of using preprocessing pipelines:
#     #
#     # https://scikit-learn.org/stable/auto_examples/compose/plot_column_transformer_mixed_types.html
#     #
#     # We will train our classifier with the following features:
#     # Numeric Features:
#     # - length:  Longest shell measurement
#     # - diameter: Diameter perpendicular to length
#     # - height:  Height with meat in shell
#     # - whole_weight: Weight of whole abalone
#     # - shucked_weight: Weight of meat
#     # - viscera_weight: Gut weight (after bleeding)
#     # - shell_weight: Weight after being dried
#     # Categorical Features:
#     # - sex: categories encoded as strings {'M', 'F', 'I'} where 'I' is Infant
#     numeric_transformer = make_pipeline(
#         SimpleImputer(strategy='median'),
#         StandardScaler())
#
#     categorical_transformer = make_pipeline(
#         SimpleImputer(strategy='constant', fill_value='missing'),
#         OneHotEncoder(handle_unknown='ignore'))
#
#     preprocessor = ColumnTransformer(transformers=[
#             ("num", numeric_transformer, make_column_selector(dtype_exclude="category")),
#             ("cat", categorical_transformer, make_column_selector(dtype_include="category"))])
#
#     preprocessor.fit(concat_data)
#
#     joblib.dump(preprocessor, os.path.join(args.model_dir, "model.joblib"))
#
#     print("saved model!")
#
#
# def input_fn(input_data, content_type):
#     """Parse input data payload
#
#     We currently only take csv input. Since we need to process both labelled
#     and unlabelled data we first determine whether the label column is present
#     by looking at how many columns were provided.
#     """
#     if content_type == 'text/csv':
#         # Read the raw input data as CSV.
#         df = pd.read_csv(StringIO(input_data),
#                          header=None)
#
#         if len(df.columns) == len(feature_columns_names) + 1:
#             # This is a labelled example, includes the ring label
#             df.columns = feature_columns_names + [label_column]
#         elif len(df.columns) == len(feature_columns_names):
#             # This is an unlabelled example.
#             df.columns = feature_columns_names
#
#         return df
#     else:
#         raise ValueError("{} not supported by script!".format(content_type))
#
#
# def output_fn(prediction, accept):
#     """Format prediction output
#
#     The default accept/content-type between containers for serial inference is JSON.
#     We also want to set the ContentType or mimetype as the same value as accept so the next
#     container can read the response payload correctly.
#     """
#     if accept == "application/json":
#         instances = []
#         for row in prediction.tolist():
#             instances.append({"features": row})
#
#         json_output = {"instances": instances}
#
#         return worker.Response(json.dumps(json_output), mimetype=accept)
#     elif accept == 'text/csv':
#         return worker.Response(encoders.encode(prediction, accept), mimetype=accept)
#     else:
#         raise RuntimeException("{} accept type is not supported by this script.".format(accept))
#
#
# def predict_fn(input_data, model):
#     """Preprocess input data
#
#     We implement this because the default predict_fn uses .predict(), but our model is a preprocessor
#     so we want to use .transform().
#
#     The output is returned in the following order:
#
#         rest of features either one hot encoded or standardized
#     """
#     features = model.transform(input_data)
#
#     if label_column in input_data:
#         # Return the label (as the first column) and the set of features.
#         return np.insert(features, 0, input_data[label_column], axis=1)
#     else:
#         # Return only the set of features
#         return features
#
#
# def model_fn(model_dir):
#     """Deserialize fitted model
#     """
#     preprocessor = joblib.load(os.path.join(model_dir, "model.joblib"))
#     return preprocessor
# ```

# %% [markdown]
# ## Create SageMaker Scikit Estimator <a class="anchor" id="create_sklearn_estimator"></a>
#
# To run our Scikit-learn training script on SageMaker, we construct a `sagemaker.sklearn.estimator.sklearn` estimator, which accepts several constructor arguments:
#
# * __entry_point__: The path to the Python script SageMaker runs for training and prediction.
# * __role__: Role ARN
# * __framework_version__: Scikit-learn version you want to use for executing your model training code.
# * __train_instance_type__ *(optional)*: The type of SageMaker instances for training. __Note__: Because Scikit-learn does not natively support GPU training, Sagemaker Scikit-learn does not currently support training on GPU instance types.
# * __sagemaker_session__ *(optional)*: The session used to train on Sagemaker.
#
# To see the code for the SKLearn Estimator, see here: https://github.com/aws/sagemaker-python-sdk/tree/master/src/sagemaker/sklearn

# %%
from sagemaker.sklearn.estimator import SKLearn

FRAMEWORK_VERSION = "0.23-1"
script_path = 'sklearn_abalone_featurizer.py'

sklearn_preprocessor = SKLearn(
    entry_point=script_path,
    role=role,
    framework_version=FRAMEWORK_VERSION,
    train_instance_type="ml.c4.xlarge",
    sagemaker_session=sagemaker_session)

# %%
sklearn_preprocessor.fit({'train': train_input})
# Out:
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 2020-09-16 10:57:28 Starting - Starting the training job...
# 2020-09-16 10:57:30 Starting - Launching requested ML instances.........
# 2020-09-16 10:59:02 Starting - Preparing the instances for training......
# 2020-09-16 11:00:08 Downloading - Downloading input data...
# 2020-09-16 11:00:37 Training - Downloading the training image..
# 2020-09-16 11:01:25 Uploading - Uploading generated training model
# 2020-09-16 11:01:25 Completed - Training job completed
# Training seconds: 77
# Billable seconds: 77

# %% [markdown]
# ## Batch transform our training data <a class="anchor" id="preprocess_train_data"></a>
# Now that our proprocessor is properly fitted, let's go ahead and preprocess our training data. Let's use batch transform to directly preprocess the raw data and store right back into s3.

# %%
# Define a SKLearn Transformer from the trained SKLearn Estimator
transformer = sklearn_preprocessor.transformer(
    instance_count=1, 
    instance_type='ml.m5.xlarge',
    assemble_with = 'Line',
    accept = 'text/csv')
# Out:
# Parameter image will be renamed to image_uri in SageMaker Python SDK v2.

# %%
# Preprocess training input
transformer.transform(train_input, content_type="text/csv")
print("Waiting for transform job: " + transformer.latest_transform_job.job_name)
transformer.wait()
preprocessed_train = transformer.output_path
# Out:
# Waiting for transform job: sagemaker-scikit-learn-2020-09-14-10-21-40-642
# ..............................
# 2020-09-14T10:26:30.033:[sagemaker logs]: MaxConcurrentTransforms=1, MaxPayloadInMB=6, BatchStrategy=MULTI_RECORD
# 2020-09-14 10:26:26,790 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2020-09-14 10:26:26,792 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2020-09-14 10:26:26,793 INFO - sagemaker-containers - nginx config:
# worker_processes auto;
# daemon off;
# pid /tmp/nginx.pid;
# error_log  /dev/stderr;
#
# 2020-09-14 10:26:26,790 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2020-09-14 10:26:26,792 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 2020-09-14 10:26:26,793 INFO - sagemaker-containers - nginx config:
# worker_processes auto;
# daemon off;
# pid /tmp/nginx.pid;
# error_log  /dev/stderr;
#
# worker_rlimit_nofile 4096;
#
# events {
#   worker_connections 2048;
# }
#
# http {
#   include /etc/nginx/mime.types;
#   default_type application/octet-stream;
#   access_log /dev/stdout combined;
#
#   upstream gunicorn {
#     server unix:/tmp/gunicorn.sock;
#   }
#
#   server {
#     listen 8080 deferred;
#     client_max_body_size 0;
#
#     keepalive_timeout 3;
#
#     location ~ ^/(ping|invocations|execution-parameters) {
#       proxy_set_header X-Forwarded-For $proxy_add_x_forwarded_for;
#       proxy_set_header Host $http_host;
#       proxy_redirect off;
#       proxy_read_timeout 60s;
#       proxy_pass http://gunicorn;
#     }
#
#     location / {
#       return 404 "{}";
#     }
#
#   }
# }
#
#
# 2020/09/14 10:26:26 [crit] 13#13: *1 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [14/Sep/2020:10:26:26 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2020-09-14 10:26:26,933 INFO - sagemaker-containers - Module sklearn_abalone_featurizer does not provide a setup.py.
# Generating setup.py
# 2020-09-14 10:26:26,934 INFO - sagemaker-containers - Generating setup.cfg
# 2020-09-14 10:26:26,934 INFO - sagemaker-containers - Generating MANIFEST.in
# 2020-09-14 10:26:26,934 INFO - sagemaker-containers - Installing module with the following command:
# /miniconda3/bin/python -m pip install .
# 2020/09/14 10:26:26 [crit] 13#13: *3 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [14/Sep/2020:10:26:26 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2020/09/14 10:26:27 [crit] 13#13: *5 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [14/Sep/2020:10:26:27 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2020/09/14 10:26:27 [crit] 13#13: *7 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [14/Sep/2020:10:26:27 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# Processing /opt/ml/code
# 2020/09/14 10:26:27 [crit] 13#13: *9 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [14/Sep/2020:10:26:27 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2020/09/14 10:26:27 [crit] 13#13: *11 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [14/Sep/2020:10:26:27 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# Building wheels for collected packages: sklearn-abalone-featurizer
#   Building wheel for sklearn-abalone-featurizer (setup.py): started
# 2020/09/14 10:26:27 [crit] 13#13: *13 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [14/Sep/2020:10:26:27 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2020/09/14 10:26:27 [crit] 13#13: *15 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [14/Sep/2020:10:26:27 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
#   Building wheel for sklearn-abalone-featurizer (setup.py): finished with status 'done'
#   Created wheel for sklearn-abalone-featurizer: filename=sklearn_abalone_featurizer-1.0.0-py2.py3-none-any.whl size=9905 sha256=21b63de71ff2c4d91eb7b129076615597dda9c6717956429292ac4bb594dad3b
#   Stored in directory: /home/model-server/tmp/pip-ephem-wheel-cache-xjvv1ek2/wheels/3e/0f/51/2f1df833dd0412c1bc2f5ee56baac195b5be563353d111dca6
# Successfully built sklearn-abalone-featurizer
# 2020/09/14 10:26:27 [crit] 13#13: *17 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [14/Sep/2020:10:26:27 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2020/09/14 10:26:27 [crit] 13#13: *19 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [14/Sep/2020:10:26:27 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# worker_rlimit_nofile 4096;
#
# events {
#   worker_connections 2048;
# }
#
# http {
#   include /etc/nginx/mime.types;
#   default_type application/octet-stream;
#   access_log /dev/stdout combined;
#
#   upstream gunicorn {
#     server unix:/tmp/gunicorn.sock;
#   }
#
#   server {
#     listen 8080 deferred;
#     client_max_body_size 0;
#
#     keepalive_timeout 3;
#
#     location ~ ^/(ping|invocations|execution-parameters) {
#       proxy_set_header X-Forwarded-For $proxy_add_x_forwarded_for;
#       proxy_set_header Host $http_host;
#       proxy_redirect off;
#       proxy_read_timeout 60s;
#       proxy_pass http://gunicorn;
#     }
#
#     location / {
#       return 404 "{}";
#     }
#
#   }
# }
#
#
# 2020/09/14 10:26:26 [crit] 13#13: *1 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [14/Sep/2020:10:26:26 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2020-09-14 10:26:26,933 INFO - sagemaker-containers - Module sklearn_abalone_featurizer does not provide a setup.py.
# Generating setup.py
# 2020-09-14 10:26:26,934 INFO - sagemaker-containers - Generating setup.cfg
# 2020-09-14 10:26:26,934 INFO - sagemaker-containers - Generating MANIFEST.in
# 2020-09-14 10:26:26,934 INFO - sagemaker-containers - Installing module with the following command:
# /miniconda3/bin/python -m pip install .
# 2020/09/14 10:26:26 [crit] 13#13: *3 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [14/Sep/2020:10:26:26 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2020/09/14 10:26:27 [crit] 13#13: *5 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [14/Sep/2020:10:26:27 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2020/09/14 10:26:27 [crit] 13#13: *7 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [14/Sep/2020:10:26:27 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# Processing /opt/ml/code
# 2020/09/14 10:26:27 [crit] 13#13: *9 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [14/Sep/2020:10:26:27 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2020/09/14 10:26:27 [crit] 13#13: *11 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [14/Sep/2020:10:26:27 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# Building wheels for collected packages: sklearn-abalone-featurizer
#   Building wheel for sklearn-abalone-featurizer (setup.py): started
# 2020/09/14 10:26:27 [crit] 13#13: *13 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [14/Sep/2020:10:26:27 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2020/09/14 10:26:27 [crit] 13#13: *15 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [14/Sep/2020:10:26:27 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
#   Building wheel for sklearn-abalone-featurizer (setup.py): finished with status 'done'
#   Created wheel for sklearn-abalone-featurizer: filename=sklearn_abalone_featurizer-1.0.0-py2.py3-none-any.whl size=9905 sha256=21b63de71ff2c4d91eb7b129076615597dda9c6717956429292ac4bb594dad3b
#   Stored in directory: /home/model-server/tmp/pip-ephem-wheel-cache-xjvv1ek2/wheels/3e/0f/51/2f1df833dd0412c1bc2f5ee56baac195b5be563353d111dca6
# Successfully built sklearn-abalone-featurizer
# 2020/09/14 10:26:27 [crit] 13#13: *17 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [14/Sep/2020:10:26:27 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2020/09/14 10:26:27 [crit] 13#13: *19 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [14/Sep/2020:10:26:27 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# Installing collected packages: sklearn-abalone-featurizer
# Successfully installed sklearn-abalone-featurizer-1.0.0
# 2020/09/14 10:26:27 [crit] 13#13: *21 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [14/Sep/2020:10:26:27 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2020/09/14 10:26:27 [crit] 13#13: *23 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [14/Sep/2020:10:26:27 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2020/09/14 10:26:28 [crit] 13#13: *25 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [14/Sep/2020:10:26:28 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2020/09/14 10:26:28 [crit] 13#13: *27 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [14/Sep/2020:10:26:28 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2020/09/14 10:26:28 [crit] 13#13: *29 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [14/Sep/2020:10:26:28 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2020/09/14 10:26:28 [crit] 13#13: *31 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [14/Sep/2020:10:26:28 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# [2020-09-14 10:26:28 +0000] [32] [INFO] Starting gunicorn 20.0.4
# [2020-09-14 10:26:28 +0000] [32] [INFO] Listening at: unix:/tmp/gunicorn.sock (32)
# [2020-09-14 10:26:28 +0000] [32] [INFO] Using worker: gevent
# [2020-09-14 10:26:28 +0000] [35] [INFO] Booting worker with pid: 35
# [2020-09-14 10:26:28 +0000] [36] [INFO] Booting worker with pid: 36
# [2020-09-14 10:26:28 +0000] [40] [INFO] Booting worker with pid: 40
# [2020-09-14 10:26:28 +0000] [41] [INFO] Booting worker with pid: 41
# 2020-09-14 10:26:29,176 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 169.254.255.130 - - [14/Sep/2020:10:26:29 +0000] "GET /ping HTTP/1.1" 200 0 "-" "Go-http-client/1.1"
# 2020-09-14 10:26:29,642 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 169.254.255.130 - - [14/Sep/2020:10:26:30 +0000] "GET /execution-parameters HTTP/1.1" 404 232 "-" "Go-http-client/1.1"
# /miniconda3/lib/python3.7/site-packages/sklearn/compose/_column_transformer.py:440: FutureWarning: Given feature/column names or counts do not match the ones for the data given during fit. This will fail from v0.24.
#   FutureWarning)
# 169.254.255.130 - - [14/Sep/2020:10:26:30 +0000] "POST /invocations HTTP/1.1" 200 641942 "-" "Go-http-client/1.1"
# Installing collected packages: sklearn-abalone-featurizer
# Successfully installed sklearn-abalone-featurizer-1.0.0
# 2020/09/14 10:26:27 [crit] 13#13: *21 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [14/Sep/2020:10:26:27 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2020/09/14 10:26:27 [crit] 13#13: *23 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [14/Sep/2020:10:26:27 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2020/09/14 10:26:28 [crit] 13#13: *25 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [14/Sep/2020:10:26:28 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2020/09/14 10:26:28 [crit] 13#13: *27 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [14/Sep/2020:10:26:28 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2020/09/14 10:26:28 [crit] 13#13: *29 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [14/Sep/2020:10:26:28 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2020/09/14 10:26:28 [crit] 13#13: *31 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [14/Sep/2020:10:26:28 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# [2020-09-14 10:26:28 +0000] [32] [INFO] Starting gunicorn 20.0.4
# [2020-09-14 10:26:28 +0000] [32] [INFO] Listening at: unix:/tmp/gunicorn.sock (32)
# [2020-09-14 10:26:28 +0000] [32] [INFO] Using worker: gevent
# [2020-09-14 10:26:28 +0000] [35] [INFO] Booting worker with pid: 35
# [2020-09-14 10:26:28 +0000] [36] [INFO] Booting worker with pid: 36
# [2020-09-14 10:26:28 +0000] [40] [INFO] Booting worker with pid: 40
# [2020-09-14 10:26:28 +0000] [41] [INFO] Booting worker with pid: 41
# 2020-09-14 10:26:29,176 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 169.254.255.130 - - [14/Sep/2020:10:26:29 +0000] "GET /ping HTTP/1.1" 200 0 "-" "Go-http-client/1.1"
# 2020-09-14 10:26:29,642 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# 169.254.255.130 - - [14/Sep/2020:10:26:30 +0000] "GET /execution-parameters HTTP/1.1" 404 232 "-" "Go-http-client/1.1"
# /miniconda3/lib/python3.7/site-packages/sklearn/compose/_column_transformer.py:440: FutureWarning: Given feature/column names or counts do not match the ones for the data given during fit. This will fail from v0.24.
#   FutureWarning)
# 169.254.255.130 - - [14/Sep/2020:10:26:30 +0000] "POST /invocations HTTP/1.1" 200 641942 "-" "Go-http-client/1.1"

# %% [markdown]
# ## Fit a LinearLearner Model with the preprocessed data <a class="anchor" id="training_model"></a>
# Let's take the preprocessed training data and fit a LinearLearner Model. Sagemaker provides prebuilt algorithm containers that can be used with the Python SDK. The previous Scikit-learn job preprocessed the raw Titanic dataset into labeled, useable data that we can now use to fit a binary classifier Linear Learner model.
#
# For more on Linear Learner see: https://docs.aws.amazon.com/sagemaker/latest/dg/linear-learner.html

# %%
import boto3
from sagemaker.amazon.amazon_estimator import get_image_uri
ll_image = get_image_uri(boto3.Session().region_name, 'linear-learner')
# Out:
# 'get_image_uri' method will be deprecated in favor of 'ImageURIProvider' class in SageMaker Python SDK v2.

# %%
s3_ll_output_key_prefix = "ll_training_output"
s3_ll_output_location = 's3://{}/{}/{}/{}'.format(bucket, prefix, s3_ll_output_key_prefix, 'll_model')

ll_estimator = sagemaker.estimator.Estimator(
    ll_image,
    role, 
    train_instance_count=1, 
    train_instance_type='ml.m4.2xlarge', # ml.m4.2xlarge | 
    train_volume_size = 20,
    train_max_run = 3600,
    input_mode= 'File',
    output_path=s3_ll_output_location,
    sagemaker_session=sagemaker_session)

ll_estimator.set_hyperparameters(feature_dim=10, predictor_type='regressor', mini_batch_size=32)

ll_train_data = sagemaker.session.s3_input(
    preprocessed_train, 
    distribution='FullyReplicated',
    content_type='text/csv', 
    s3_data_type='S3Prefix')

data_channels = {'train': ll_train_data}
ll_estimator.fit(inputs=data_channels, logs=True)
# Out:
# Parameter image_name will be renamed to image_uri in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 2020-09-14 10:27:25 Starting - Starting the training job...
# 2020-09-14 10:27:27 Starting - Launching requested ML instances.........
# 2020-09-14 10:28:58 Starting - Preparing the instances for training...
# 2020-09-14 10:29:45 Downloading - Downloading input data...
# 2020-09-14 10:30:22 Training - Training image download completed. Training in progress..Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [09/14/2020 10:30:27 INFO 140546488739648] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-input.json: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'auto', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [09/14/2020 10:30:27 INFO 140546488739648] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {u'feature_dim': u'10', u'mini_batch_size': u'32', u'predictor_type': u'regressor'}
# [09/14/2020 10:30:27 INFO 140546488739648] Final configuration: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'10', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'32', u'huber_delta': u'1.0', u'num_classes': u'1', u'predictor_type': u'regressor', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [09/14/2020 10:30:27 WARNING 140546488739648] Loggers have already been setup.
# Process 1 is a worker.
# [09/14/2020 10:30:27 INFO 140546488739648] Using default worker.
# [09/14/2020 10:30:27 INFO 140546488739648] Checkpoint loading and saving are disabled.
# [09/14/2020 10:30:27 INFO 140546488739648] Create Store: local
# [09/14/2020 10:30:28 INFO 140546488739648] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7fd32b712b50>
# [09/14/2020 10:30:28 INFO 140546488739648] Scaling model computed with parameters:
#  {'stdev_weight':
# [1.0008885  1.0007699  1.0006139  1.0006258  1.0004948  1.0006459
#  1.0008249  0.46370664 0.46710354 0.4815377 ]
# <NDArray 10 @cpu(0)>, 'stdev_label':
# [3.2286315]
# <NDArray 1 @cpu(0)>, 'mean_label':
# [9.936298]
# <NDArray 1 @cpu(0)>, 'mean_weight':
# [-8.4352265e-05  1.3075861e-04  1.0231711e-05  2.6012820e-04
#  -6.1455023e-05  1.6360203e-04  6.7376607e-04  3.1298077e-01
#   3.2163462e-01  3.6538455e-01]
# <NDArray 10 @cpu(0)>}
# [09/14/2020 10:30:28 INFO 140546488739648] nvidia-smi took: 0.0251820087433 secs to identify 0 gpus
# [09/14/2020 10:30:28 INFO 140546488739648] Number of GPUs being used: 0
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 131, "sum": 131.0, "min": 131}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 132, "sum": 132.0, "min": 132}, "Total Records Seen": {"count": 1, "max": 4209, "sum": 4209.0, "min": 4209}, "Max Records Seen Between Resets": {"count": 1, "max": 4177, "sum": 4177.0, "min": 4177}, "Reset Count": {"count": 1, "max": 2, "sum": 2.0, "min": 2}}, "EndTime": 1600079428.386985, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1600079428.386949}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8006994443730666, "sum": 0.8006994443730666, "min": 0.8006994443730666}}, "EndTime": 1600079430.909428, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1600079430.909362}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.7895342076053986, "sum": 0.7895342076053986, "min": 0.7895342076053986}}, "EndTime": 1600079430.90952, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1600079430.909501}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8145962285880859, "sum": 0.8145962285880859, "min": 0.8145962285880859}}, "EndTime": 1600079430.909584, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1600079430.909567}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8084361936037358, "sum": 0.8084361936037358, "min": 0.8084361936037358}}, "EndTime": 1600079430.909646, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1600079430.909629}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.046785618708684, "sum": 1.046785618708684, "min": 1.046785618708684}}, "EndTime": 1600079430.90971, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1600079430.909692}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.004103499937516, "sum": 1.004103499937516, "min": 1.004103499937516}}, "EndTime": 1600079430.909772, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1600079430.909756}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0218661696291886, "sum": 1.0218661696291886, "min": 1.0218661696291886}}, "EndTime": 1600079430.909833, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1600079430.909817}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0797597517187778, "sum": 1.0797597517187778, "min": 1.0797597517187778}}, "EndTime": 1600079430.909895, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1600079430.909879}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.7791782177411593, "sum": 0.7791782177411593, "min": 0.7791782177411593}}, "EndTime": 1600079430.909956, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1600079430.909939}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.7981263214005874, "sum": 0.7981263214005874, "min": 0.7981263214005874}}, "EndTime": 1600079430.910012, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1600079430.909996}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8037963285755653, "sum": 0.8037963285755653, "min": 0.8037963285755653}}, "EndTime": 1600079430.910072, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1600079430.910056}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.7818726788919705, "sum": 0.7818726788919705, "min": 0.7818726788919705}}, "EndTime": 1600079430.910131, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1600079430.910115}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0660257848409507, "sum": 1.0660257848409507, "min": 1.0660257848409507}}, "EndTime": 1600079430.91019, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1600079430.910175}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9897480924542134, "sum": 0.9897480924542134, "min": 0.9897480924542134}}, "EndTime": 1600079430.910248, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1600079430.910232}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0237139691527073, "sum": 1.0237139691527073, "min": 1.0237139691527073}}, "EndTime": 1600079430.910312, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1600079430.910296}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0417327791452409, "sum": 1.0417327791452409, "min": 1.0417327791452409}}, "EndTime": 1600079430.91037, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1600079430.910354}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.7922086840065626, "sum": 0.7922086840065626, "min": 0.7922086840065626}}, "EndTime": 1600079430.910433, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1600079430.910416}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8191620367077681, "sum": 0.8191620367077681, "min": 0.8191620367077681}}, "EndTime": 1600079430.910495, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1600079430.910479}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8102897928884396, "sum": 0.8102897928884396, "min": 0.8102897928884396}}, "EndTime": 1600079430.910554, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1600079430.910538}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8241683202867325, "sum": 0.8241683202867325, "min": 0.8241683202867325}}, "EndTime": 1600079430.910609, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1600079430.910593}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9851121689264591, "sum": 0.9851121689264591, "min": 0.9851121689264591}}, "EndTime": 1600079430.910671, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1600079430.910655}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9940447032451629, "sum": 0.9940447032451629, "min": 0.9940447032451629}}, "EndTime": 1600079430.910729, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1600079430.910713}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0119658736082224, "sum": 1.0119658736082224, "min": 1.0119658736082224}}, "EndTime": 1600079430.910792, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1600079430.910777}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9945375186892657, "sum": 0.9945375186892657, "min": 0.9945375186892657}}, "EndTime": 1600079430.910852, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1600079430.910836}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.022876473917411, "sum": 1.022876473917411, "min": 1.022876473917411}}, "EndTime": 1600079430.910911, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1600079430.910895}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0269699039367528, "sum": 1.0269699039367528, "min": 1.0269699039367528}}, "EndTime": 1600079430.91097, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1600079430.910954}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0334846535554298, "sum": 1.0334846535554298, "min": 1.0334846535554298}}, "EndTime": 1600079430.911025, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1600079430.91101}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0311856883649642, "sum": 1.0311856883649642, "min": 1.0311856883649642}}, "EndTime": 1600079430.911085, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1600079430.911069}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.2156258039176464, "sum": 1.2156258039176464, "min": 1.2156258039176464}}, "EndTime": 1600079430.911146, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1600079430.91113}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.2209834496562297, "sum": 1.2209834496562297, "min": 1.2209834496562297}}, "EndTime": 1600079430.911208, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1600079430.911193}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.213840448627105, "sum": 1.213840448627105, "min": 1.213840448627105}}, "EndTime": 1600079430.911266, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1600079430.911251}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.229076458227176, "sum": 1.229076458227176, "min": 1.229076458227176}}, "EndTime": 1600079430.911326, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1600079430.91131}
#
# [09/14/2020 10:30:30 INFO 140546488739648] #quality_metric: host=algo-1, epoch=0, train mse_objective <loss>=0.800699444373
# [09/14/2020 10:30:30 INFO 140546488739648] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=mse_objective, value=0.779178217741
# [09/14/2020 10:30:30 INFO 140546488739648] Epoch 0: Loss improved. Updating best model
# [09/14/2020 10:30:30 INFO 140546488739648] Saving model for epoch: 0
# [09/14/2020 10:30:30 INFO 140546488739648] Saved checkpoint to "/tmp/tmpwsYGw5/mx-mod-0000.params"
# [09/14/2020 10:30:30 INFO 140546488739648] #progress_metric: host=algo-1, completed 6 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 131, "sum": 131.0, "min": 131}, "Number of Batches Since Last Reset": {"count": 1, "max": 131, "sum": 131.0, "min": 131}, "Number of Records Since Last Reset": {"count": 1, "max": 4177, "sum": 4177.0, "min": 4177}, "Total Batches Seen": {"count": 1, "max": 263, "sum": 263.0, "min": 263}, "Total Records Seen": {"count": 1, "max": 8386, "sum": 8386.0, "min": 8386}, "Max Records Seen Between Resets": {"count": 1, "max": 4177, "sum": 4177.0, "min": 4177}, "Reset Count": {"count": 1, "max": 3, "sum": 3.0, "min": 3}}, "EndTime": 1600079430.922324, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1600079428.387229}
#
# [09/14/2020 10:30:30 INFO 140546488739648] #throughput_metric: host=algo-1, train throughput=1647.60308428 records/second
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.7001717660576106, "sum": 0.7001717660576106, "min": 0.7001717660576106}}, "EndTime": 1600079433.566001, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1600079433.565936}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.6973204490083914, "sum": 0.6973204490083914, "min": 0.6973204490083914}}, "EndTime": 1600079433.566083, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1600079433.56607}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.7065225136108123, "sum": 0.7065225136108123, "min": 0.7065225136108123}}, "EndTime": 1600079433.566149, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1600079433.566131}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.7036212655214164, "sum": 0.7036212655214164, "min": 0.7036212655214164}}, "EndTime": 1600079433.566215, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1600079433.566198}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8627391616885479, "sum": 0.8627391616885479, "min": 0.8627391616885479}}, "EndTime": 1600079433.566283, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1600079433.566264}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.179314468571773, "sum": 1.179314468571773, "min": 1.179314468571773}}, "EndTime": 1600079433.566354, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1600079433.566336}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8744738045793313, "sum": 0.8744738045793313, "min": 0.8744738045793313}}, "EndTime": 1600079433.566427, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1600079433.566409}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0559684382035182, "sum": 1.0559684382035182, "min": 1.0559684382035182}}, "EndTime": 1600079433.5665, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1600079433.566483}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.6838876023888588, "sum": 0.6838876023888588, "min": 0.6838876023888588}}, "EndTime": 1600079433.566572, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1600079433.566555}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.7048236765540563, "sum": 0.7048236765540563, "min": 0.7048236765540563}}, "EndTime": 1600079433.566642, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1600079433.566625}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.698123033115497, "sum": 0.698123033115497, "min": 0.698123033115497}}, "EndTime": 1600079433.566714, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1600079433.566695}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.6940387485692134, "sum": 0.6940387485692134, "min": 0.6940387485692134}}, "EndTime": 1600079433.566784, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1600079433.566767}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8599194626395519, "sum": 0.8599194626395519, "min": 0.8599194626395519}}, "EndTime": 1600079433.566855, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1600079433.566837}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.1895198109058234, "sum": 1.1895198109058234, "min": 1.1895198109058234}}, "EndTime": 1600079433.566924, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1600079433.566905}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8808849308926325, "sum": 0.8808849308926325, "min": 0.8808849308926325}}, "EndTime": 1600079433.566972, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1600079433.566962}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.115818346463717, "sum": 1.115818346463717, "min": 1.115818346463717}}, "EndTime": 1600079433.567011, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1600079433.567002}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.7243065136556442, "sum": 0.7243065136556442, "min": 0.7243065136556442}}, "EndTime": 1600079433.56705, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1600079433.567041}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.7415056745593365, "sum": 0.7415056745593365, "min": 0.7415056745593365}}, "EndTime": 1600079433.567086, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1600079433.567073}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.7274293859990744, "sum": 0.7274293859990744, "min": 0.7274293859990744}}, "EndTime": 1600079433.567142, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1600079433.567131}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.7442244213934128, "sum": 0.7442244213934128, "min": 0.7442244213934128}}, "EndTime": 1600079433.567193, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1600079433.567183}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9909505499097017, "sum": 0.9909505499097017, "min": 0.9909505499097017}}, "EndTime": 1600079433.567225, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1600079433.567217}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.2699522934567469, "sum": 1.2699522934567469, "min": 1.2699522934567469}}, "EndTime": 1600079433.56726, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1600079433.567251}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9665285315078038, "sum": 0.9665285315078038, "min": 0.9665285315078038}}, "EndTime": 1600079433.567291, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1600079433.567282}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.2793481969489502, "sum": 1.2793481969489502, "min": 1.2793481969489502}}, "EndTime": 1600079433.567337, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1600079433.567322}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0220398192222302, "sum": 1.0220398192222302, "min": 1.0220398192222302}}, "EndTime": 1600079433.567389, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1600079433.567379}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.030780087526028, "sum": 1.030780087526028, "min": 1.030780087526028}}, "EndTime": 1600079433.567439, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1600079433.56743}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0219831739480678, "sum": 1.0219831739480678, "min": 1.0219831739480678}}, "EndTime": 1600079433.567474, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1600079433.567466}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0308179201988072, "sum": 1.0308179201988072, "min": 1.0308179201988072}}, "EndTime": 1600079433.567505, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1600079433.567497}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.1457124363344449, "sum": 1.1457124363344449, "min": 1.1457124363344449}}, "EndTime": 1600079433.567548, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1600079433.567533}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.2532163027960521, "sum": 1.2532163027960521, "min": 1.2532163027960521}}, "EndTime": 1600079433.567606, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1600079433.567591}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.146286963728758, "sum": 1.146286963728758, "min": 1.146286963728758}}, "EndTime": 1600079433.56765, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1600079433.56764}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.2525089809527763, "sum": 1.2525089809527763, "min": 1.2525089809527763}}, "EndTime": 1600079433.567687, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1600079433.567679}
#
# [09/14/2020 10:30:33 INFO 140546488739648] #quality_metric: host=algo-1, epoch=1, train mse_objective <loss>=0.700171766058
# [09/14/2020 10:30:33 INFO 140546488739648] #early_stopping_criteria_metric: host=algo-1, epoch=1, criteria=mse_objective, value=0.683887602389
# [09/14/2020 10:30:33 INFO 140546488739648] Epoch 1: Loss improved. Updating best model
# [09/14/2020 10:30:33 INFO 140546488739648] Saving model for epoch: 1
# [09/14/2020 10:30:33 INFO 140546488739648] Saved checkpoint to "/tmp/tmpsfVj6A/mx-mod-0000.params"
# [09/14/2020 10:30:33 INFO 140546488739648] #progress_metric: host=algo-1, completed 13 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 131, "sum": 131.0, "min": 131}, "Number of Batches Since Last Reset": {"count": 1, "max": 131, "sum": 131.0, "min": 131}, "Number of Records Since Last Reset": {"count": 1, "max": 4177, "sum": 4177.0, "min": 4177}, "Total Batches Seen": {"count": 1, "max": 394, "sum": 394.0, "min": 394}, "Total Records Seen": {"count": 1, "max": 12563, "sum": 12563.0, "min": 12563}, "Max Records Seen Between Resets": {"count": 1, "max": 4177, "sum": 4177.0, "min": 4177}, "Reset Count": {"count": 1, "max": 4, "sum": 4.0, "min": 4}}, "EndTime": 1600079433.574915, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1600079430.922521}
#
# [09/14/2020 10:30:33 INFO 140546488739648] #throughput_metric: host=algo-1, train throughput=1574.74666487 records/second
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.6519517729775264, "sum": 0.6519517729775264, "min": 0.6519517729775264}}, "EndTime": 1600079436.023087, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1600079436.023022}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.6520098924636841, "sum": 0.6520098924636841, "min": 0.6520098924636841}}, "EndTime": 1600079436.023169, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1600079436.023155}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.6574880869629292, "sum": 0.6574880869629292, "min": 0.6574880869629292}}, "EndTime": 1600079436.023209, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1600079436.023199}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.6544601890903253, "sum": 0.6544601890903253, "min": 0.6544601890903253}}, "EndTime": 1600079436.023251, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1600079436.023241}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.7881466566370083, "sum": 0.7881466566370083, "min": 0.7881466566370083}}, "EndTime": 1600079436.023286, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1600079436.023278}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9661149920179294, "sum": 0.9661149920179294, "min": 0.9661149920179294}}, "EndTime": 1600079436.023324, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1600079436.023315}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.7909681402146816, "sum": 0.7909681402146816, "min": 0.7909681402146816}}, "EndTime": 1600079436.023357, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1600079436.023349}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.00139322578907, "sum": 1.00139322578907, "min": 1.00139322578907}}, "EndTime": 1600079436.02341, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1600079436.023395}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.6404789679898666, "sum": 0.6404789679898666, "min": 0.6404789679898666}}, "EndTime": 1600079436.023475, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1600079436.023458}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.6599759937478946, "sum": 0.6599759937478946, "min": 0.6599759937478946}}, "EndTime": 1600079436.02354, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1600079436.023524}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.6508619358333257, "sum": 0.6508619358333257, "min": 0.6508619358333257}}, "EndTime": 1600079436.023608, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1600079436.023592}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.6505322228830595, "sum": 0.6505322228830595, "min": 0.6505322228830595}}, "EndTime": 1600079436.023677, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1600079436.02366}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.7906161449849606, "sum": 0.7906161449849606, "min": 0.7906161449849606}}, "EndTime": 1600079436.023749, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1600079436.023731}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9731379840236444, "sum": 0.9731379840236444, "min": 0.9731379840236444}}, "EndTime": 1600079436.02382, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1600079436.023802}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.7938789807260036, "sum": 0.7938789807260036, "min": 0.7938789807260036}}, "EndTime": 1600079436.023881, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1600079436.02387}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9947246534320024, "sum": 0.9947246534320024, "min": 0.9947246534320024}}, "EndTime": 1600079436.023943, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1600079436.023926}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.7090758887621073, "sum": 0.7090758887621073, "min": 0.7090758887621073}}, "EndTime": 1600079436.02401, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1600079436.023991}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.7303772228268477, "sum": 0.7303772228268477, "min": 0.7303772228268477}}, "EndTime": 1600079436.024081, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1600079436.024064}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.7099487537947985, "sum": 0.7099487537947985, "min": 0.7099487537947985}}, "EndTime": 1600079436.024148, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1600079436.024131}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.7306845314227618, "sum": 0.7306845314227618, "min": 0.7306845314227618}}, "EndTime": 1600079436.02421, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1600079436.024192}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8529883399605751, "sum": 0.8529883399605751, "min": 0.8529883399605751}}, "EndTime": 1600079436.024274, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1600079436.024256}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0501638915676337, "sum": 1.0501638915676337, "min": 1.0501638915676337}}, "EndTime": 1600079436.024341, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1600079436.024326}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8520044893886034, "sum": 0.8520044893886034, "min": 0.8520044893886034}}, "EndTime": 1600079436.024389, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1600079436.024373}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.045590759240664, "sum": 1.045590759240664, "min": 1.045590759240664}}, "EndTime": 1600079436.024458, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1600079436.024441}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0149518224482352, "sum": 1.0149518224482352, "min": 1.0149518224482352}}, "EndTime": 1600079436.024528, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1600079436.024511}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0303320750021017, "sum": 1.0303320750021017, "min": 1.0303320750021017}}, "EndTime": 1600079436.024592, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1600079436.024574}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0150465566378373, "sum": 1.0150465566378373, "min": 1.0150465566378373}}, "EndTime": 1600079436.024652, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1600079436.024635}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.030370506300376, "sum": 1.030370506300376, "min": 1.030370506300376}}, "EndTime": 1600079436.024717, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1600079436.024705}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0912297502160073, "sum": 1.0912297502160073, "min": 1.0912297502160073}}, "EndTime": 1600079436.024779, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1600079436.024761}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.2371652521479588, "sum": 1.2371652521479588, "min": 1.2371652521479588}}, "EndTime": 1600079436.024839, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1600079436.024823}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0911415993021085, "sum": 1.0911415993021085, "min": 1.0911415993021085}}, "EndTime": 1600079436.0249, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1600079436.024884}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.2366215240496856, "sum": 1.2366215240496856, "min": 1.2366215240496856}}, "EndTime": 1600079436.024952, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1600079436.024937}
#
# [09/14/2020 10:30:36 INFO 140546488739648] #quality_metric: host=algo-1, epoch=2, train mse_objective <loss>=0.651951772978
# [09/14/2020 10:30:36 INFO 140546488739648] #early_stopping_criteria_metric: host=algo-1, epoch=2, criteria=mse_objective, value=0.64047896799
# [09/14/2020 10:30:36 INFO 140546488739648] Epoch 2: Loss improved. Updating best model
# [09/14/2020 10:30:36 INFO 140546488739648] Saving model for epoch: 2
# [09/14/2020 10:30:36 INFO 140546488739648] Saved checkpoint to "/tmp/tmpBLSy3e/mx-mod-0000.params"
# [09/14/2020 10:30:36 INFO 140546488739648] #progress_metric: host=algo-1, completed 20 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 131, "sum": 131.0, "min": 131}, "Number of Batches Since Last Reset": {"count": 1, "max": 131, "sum": 131.0, "min": 131}, "Number of Records Since Last Reset": {"count": 1, "max": 4177, "sum": 4177.0, "min": 4177}, "Total Batches Seen": {"count": 1, "max": 525, "sum": 525.0, "min": 525}, "Total Records Seen": {"count": 1, "max": 16740, "sum": 16740.0, "min": 16740}, "Max Records Seen Between Resets": {"count": 1, "max": 4177, "sum": 4177.0, "min": 4177}, "Reset Count": {"count": 1, "max": 5, "sum": 5.0, "min": 5}}, "EndTime": 1600079436.032594, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1600079433.575131}
#
# [09/14/2020 10:30:36 INFO 140546488739648] #throughput_metric: host=algo-1, train throughput=1699.62557031 records/second
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.6168782506997769, "sum": 0.6168782506997769, "min": 0.6168782506997769}}, "EndTime": 1600079438.39606, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1600079438.395994}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.6180526547707044, "sum": 0.6180526547707044, "min": 0.6180526547707044}}, "EndTime": 1600079438.396143, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1600079438.396129}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.6218000201651683, "sum": 0.6218000201651683, "min": 0.6218000201651683}}, "EndTime": 1600079438.396182, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1600079438.396173}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.6191089973999904, "sum": 0.6191089973999904, "min": 0.6191089973999904}}, "EndTime": 1600079438.396216, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1600079438.396207}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.7430261386701694, "sum": 0.7430261386701694, "min": 0.7430261386701694}}, "EndTime": 1600079438.396252, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1600079438.396244}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.975844715994138, "sum": 0.975844715994138, "min": 0.975844715994138}}, "EndTime": 1600079438.39629, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1600079438.396281}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.7459424462455969, "sum": 0.7459424462455969, "min": 0.7459424462455969}}, "EndTime": 1600079438.396327, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1600079438.396318}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9853314467347585, "sum": 0.9853314467347585, "min": 0.9853314467347585}}, "EndTime": 1600079438.396364, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1600079438.396355}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.6088087044942837, "sum": 0.6088087044942837, "min": 0.6088087044942837}}, "EndTime": 1600079438.396402, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1600079438.396393}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.6260062350103488, "sum": 0.6260062350103488, "min": 0.6260062350103488}}, "EndTime": 1600079438.396439, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1600079438.39643}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.6170925367623568, "sum": 0.6170925367623568, "min": 0.6170925367623568}}, "EndTime": 1600079438.396471, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1600079438.396463}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.618350318991221, "sum": 0.618350318991221, "min": 0.618350318991221}}, "EndTime": 1600079438.396509, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1600079438.3965}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.748884310401403, "sum": 0.748884310401403, "min": 0.748884310401403}}, "EndTime": 1600079438.39655, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1600079438.396536}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9831979611745247, "sum": 0.9831979611745247, "min": 0.9831979611745247}}, "EndTime": 1600079438.396611, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1600079438.396599}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.7499577964154573, "sum": 0.7499577964154573, "min": 0.7499577964154573}}, "EndTime": 1600079438.396668, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1600079438.396652}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9898083792282985, "sum": 0.9898083792282985, "min": 0.9898083792282985}}, "EndTime": 1600079438.396725, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1600079438.396712}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.6990965264921005, "sum": 0.6990965264921005, "min": 0.6990965264921005}}, "EndTime": 1600079438.396782, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1600079438.396767}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.7276330246948279, "sum": 0.7276330246948279, "min": 0.7276330246948279}}, "EndTime": 1600079438.396841, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1600079438.396822}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.6993824498011516, "sum": 0.6993824498011516, "min": 0.6993824498011516}}, "EndTime": 1600079438.396899, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1600079438.396884}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.7275136226071761, "sum": 0.7275136226071761, "min": 0.7275136226071761}}, "EndTime": 1600079438.396952, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1600079438.39694}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.822122009155842, "sum": 0.822122009155842, "min": 0.822122009155842}}, "EndTime": 1600079438.397007, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1600079438.396992}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.06478981925891, "sum": 1.06478981925891, "min": 1.06478981925891}}, "EndTime": 1600079438.397066, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1600079438.397049}
#
# ...
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.1595756758290987, "sum": 1.1595756758290987, "min": 1.1595756758290987}}, "EndTime": 1600079463.111737, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1600079463.11172}
#
# [09/14/2020 10:31:03 INFO 140546488739648] #quality_metric: host=algo-1, epoch=13, train mse_objective <loss>=0.508158002249
# [09/14/2020 10:31:03 INFO 140546488739648] #early_stopping_criteria_metric: host=algo-1, epoch=13, criteria=mse_objective, value=0.508158002249
# [09/14/2020 10:31:03 INFO 140546488739648] Epoch 13: Loss improved. Updating best model
# [09/14/2020 10:31:03 INFO 140546488739648] Saving model for epoch: 13
# [09/14/2020 10:31:03 INFO 140546488739648] Saved checkpoint to "/tmp/tmpWpq543/mx-mod-0000.params"
# [09/14/2020 10:31:03 INFO 140546488739648] #progress_metric: host=algo-1, completed 93 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 131, "sum": 131.0, "min": 131}, "Number of Batches Since Last Reset": {"count": 1, "max": 131, "sum": 131.0, "min": 131}, "Number of Records Since Last Reset": {"count": 1, "max": 4177, "sum": 4177.0, "min": 4177}, "Total Batches Seen": {"count": 1, "max": 1966, "sum": 1966.0, "min": 1966}, "Total Records Seen": {"count": 1, "max": 62687, "sum": 62687.0, "min": 62687}, "Max Records Seen Between Resets": {"count": 1, "max": 4177, "sum": 4177.0, "min": 4177}, "Reset Count": {"count": 1, "max": 16, "sum": 16.0, "min": 16}}, "EndTime": 1600079463.119738, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1600079460.736347}
#
# [09/14/2020 10:31:03 INFO 140546488739648] #throughput_metric: host=algo-1, train throughput=1752.46776973 records/second
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.5049519658661805, "sum": 0.5049519658661805, "min": 0.5049519658661805}}, "EndTime": 1600079465.595955, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1600079465.595888}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.5272593611708054, "sum": 0.5272593611708054, "min": 0.5272593611708054}}, "EndTime": 1600079465.596045, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1600079465.596025}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.5060797868153224, "sum": 0.5060797868153224, "min": 0.5060797868153224}}, "EndTime": 1600079465.596107, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1600079465.59609}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.5281690770043777, "sum": 0.5281690770043777, "min": 0.5281690770043777}}, "EndTime": 1600079465.596165, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1600079465.596148}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.6009371630274333, "sum": 0.6009371630274333, "min": 0.6009371630274333}}, "EndTime": 1600079465.596233, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1600079465.596216}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8775273772959525, "sum": 0.8775273772959525, "min": 0.8775273772959525}}, "EndTime": 1600079465.59629, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1600079465.596274}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.6022815406322479, "sum": 0.6022815406322479, "min": 0.6022815406322479}}, "EndTime": 1600079465.596344, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1600079465.596328}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8775075801289999, "sum": 0.8775075801289999, "min": 0.8775075801289999}}, "EndTime": 1600079465.596411, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1600079465.596394}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.5063640413376002, "sum": 0.5063640413376002, "min": 0.5063640413376002}}, "EndTime": 1600079465.596469, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1600079465.596453}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.5319387781505401, "sum": 0.5319387781505401, "min": 0.5319387781505401}}, "EndTime": 1600079465.596524, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1600079465.596508}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.5091643071805055, "sum": 0.5091643071805055, "min": 0.5091643071805055}}, "EndTime": 1600079465.596587, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1600079465.596571}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.5320566235826566, "sum": 0.5320566235826566, "min": 0.5320566235826566}}, "EndTime": 1600079465.596649, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1600079465.596633}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.6102002832178887, "sum": 0.6102002832178887, "min": 0.6102002832178887}}, "EndTime": 1600079465.59671, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1600079465.596693}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8805003965130219, "sum": 0.8805003965130219, "min": 0.8805003965130219}}, "EndTime": 1600079465.596769, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1600079465.596752}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.6102184898578203, "sum": 0.6102184898578203, "min": 0.6102184898578203}}, "EndTime": 1600079465.596834, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1600079465.596817}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8805009269943604, "sum": 0.8805009269943604, "min": 0.8805009269943604}}, "EndTime": 1600079465.596897, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1600079465.596881}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.6447012203244062, "sum": 0.6447012203244062, "min": 0.6447012203244062}}, "EndTime": 1600079465.596962, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1600079465.596946}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.7176201901183679, "sum": 0.7176201901183679, "min": 0.7176201901183679}}, "EndTime": 1600079465.597016, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1600079465.597001}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.6447017704065029, "sum": 0.6447017704065029, "min": 0.6447017704065029}}, "EndTime": 1600079465.59708, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1600079465.597064}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.7176038064062595, "sum": 0.7176038064062595, "min": 0.7176038064062595}}, "EndTime": 1600079465.597144, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1600079465.597128}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8229257752975592, "sum": 0.8229257752975592, "min": 0.8229257752975592}}, "EndTime": 1600079465.597227, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1600079465.597189}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9339442109832397, "sum": 0.9339442109832397, "min": 0.9339442109832397}}, "EndTime": 1600079465.5973, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1600079465.597281}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8229299902915954, "sum": 0.8229299902915954, "min": 0.8229299902915954}}, "EndTime": 1600079465.597363, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1600079465.597347}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9339332132671888, "sum": 0.9339332132671888, "min": 0.9339332132671888}}, "EndTime": 1600079465.597407, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1600079465.597397}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9719939017525085, "sum": 0.9719939017525085, "min": 0.9719939017525085}}, "EndTime": 1600079465.597453, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1600079465.597438}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0217380128227747, "sum": 1.0217380128227747, "min": 1.0217380128227747}}, "EndTime": 1600079465.597516, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1600079465.5975}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9720259943833718, "sum": 0.9720259943833718, "min": 0.9720259943833718}}, "EndTime": 1600079465.59758, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1600079465.597563}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.021765240167196, "sum": 1.021765240167196, "min": 1.021765240167196}}, "EndTime": 1600079465.597647, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1600079465.597629}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0845864003667465, "sum": 1.0845864003667465, "min": 1.0845864003667465}}, "EndTime": 1600079465.597719, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1600079465.597702}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.1515499958625206, "sum": 1.1515499958625206, "min": 1.1515499958625206}}, "EndTime": 1600079465.597781, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1600079465.597764}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.084577843776116, "sum": 1.084577843776116, "min": 1.084577843776116}}, "EndTime": 1600079465.597844, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1600079465.597827}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.151498135064657, "sum": 1.151498135064657, "min": 1.151498135064657}}, "EndTime": 1600079465.597902, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1600079465.597888}
#
# [09/14/2020 10:31:05 INFO 140546488739648] #quality_metric: host=algo-1, epoch=14, train mse_objective <loss>=0.504951965866
# [09/14/2020 10:31:05 INFO 140546488739648] #early_stopping_criteria_metric: host=algo-1, epoch=14, criteria=mse_objective, value=0.504951965866
# [09/14/2020 10:31:05 INFO 140546488739648] Epoch 14: Loss improved. Updating best model
# [09/14/2020 10:31:05 INFO 140546488739648] Saving model for epoch: 14
# [09/14/2020 10:31:05 INFO 140546488739648] Saved checkpoint to "/tmp/tmplKixZz/mx-mod-0000.params"
# [09/14/2020 10:31:05 INFO 140546488739648] #progress_metric: host=algo-1, completed 100 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 131, "sum": 131.0, "min": 131}, "Number of Batches Since Last Reset": {"count": 1, "max": 131, "sum": 131.0, "min": 131}, "Number of Records Since Last Reset": {"count": 1, "max": 4177, "sum": 4177.0, "min": 4177}, "Total Batches Seen": {"count": 1, "max": 2097, "sum": 2097.0, "min": 2097}, "Total Records Seen": {"count": 1, "max": 66864, "sum": 66864.0, "min": 66864}, "Max Records Seen Between Resets": {"count": 1, "max": 4177, "sum": 4177.0, "min": 4177}, "Reset Count": {"count": 1, "max": 17, "sum": 17.0, "min": 17}}, "EndTime": 1600079465.605023, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1600079463.119935}
#
# [09/14/2020 10:31:05 INFO 140546488739648] #throughput_metric: host=algo-1, train throughput=1680.73864054 records/second
# [09/14/2020 10:31:05 WARNING 140546488739648] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [09/14/2020 10:31:05 WARNING 140546488739648] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [09/14/2020 10:31:05 INFO 140546488739648] #train_score (algo-1) : ('mse_objective', 5.101136843896181)
# [09/14/2020 10:31:05 INFO 140546488739648] #train_score (algo-1) : ('mse', 5.101136843896181)
# [09/14/2020 10:31:05 INFO 140546488739648] #train_score (algo-1) : ('absolute_loss', 1.5949838755659889)
# [09/14/2020 10:31:05 INFO 140546488739648] #quality_metric: host=algo-1, train mse_objective <loss>=5.1011368439
# [09/14/2020 10:31:05 INFO 140546488739648] #quality_metric: host=algo-1, train mse <loss>=5.1011368439
# [09/14/2020 10:31:05 INFO 140546488739648] #quality_metric: host=algo-1, train absolute_loss <loss>=1.59498387557
# [09/14/2020 10:31:05 INFO 140546488739648] Best model found for hyperparameters: {"lr_scheduler_step": 10, "wd": 0.0001, "optimizer": "adam", "lr_scheduler_factor": 0.99, "l1": 0.0, "learning_rate": 0.005, "lr_scheduler_minimum_lr": 1e-05}
# [09/14/2020 10:31:05 INFO 140546488739648] Saved checkpoint to "/tmp/tmpdJsB6l/mx-mod-0000.params"
# [09/14/2020 10:31:05 INFO 140546488739648] Test data is not provided.
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 38540.50517082214, "sum": 38540.50517082214, "min": 38540.50517082214}, "finalize.time": {"count": 1, "max": 368.988037109375, "sum": 368.988037109375, "min": 368.988037109375}, "initialize.time": {"count": 1, "max": 717.9651260375977, "sum": 717.9651260375977, "min": 717.9651260375977}, "check_early_stopping.time": {"count": 15, "max": 1.096963882446289, "sum": 14.261007308959961, "min": 0.8649826049804688}, "setuptime": {"count": 1, "max": 28.806209564208984, "sum": 28.806209564208984, "min": 28.806209564208984}, "update.time": {"count": 15, "max": 2650.0442028045654, "sum": 37168.71976852417, "min": 2321.00510597229}, "epochs": {"count": 1, "max": 15, "sum": 15.0, "min": 15}}, "EndTime": 1600079465.979664, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1600079427.668787}
# 2020-09-14 10:31:15 Uploading - Uploading generated training model
# 2020-09-14 10:31:15 Completed - Training job completed
# Training seconds: 90
# Billable seconds: 90

# %% [markdown]
# # Serial Inference Pipeline with Scikit preprocessor and Linear Learner <a class="anchor" id="serial_inference"></a>

# %% [markdown]
# ## Set up the inference pipeline <a class="anchor" id="pipeline_setup"></a>
# Setting up a Machine Learning pipeline can be done with the Pipeline Model. This sets up a list of models in a single endpoint; in this example, we configure our pipeline model with the fitted Scikit-learn inference model and the fitted Linear Learner model. Deploying the model follows the same ```deploy``` pattern in the SDK.

# %%
from sagemaker.model import Model
from sagemaker.pipeline import PipelineModel
import boto3
from time import gmtime, strftime

timestamp_prefix = strftime("%Y-%m-%d-%H-%M-%S", gmtime())

scikit_learn_inferencee_model = sklearn_preprocessor.create_model()
linear_learner_model = ll_estimator.create_model()

model_name = 'inference-pipeline-' + timestamp_prefix
endpoint_name = 'inference-pipeline-ep-' + timestamp_prefix
sm_model = PipelineModel(
    name=model_name, 
    role=role, 
    models=[
        scikit_learn_inferencee_model, 
        linear_learner_model])

#sm_model.deploy(initial_instance_count=1, instance_type='ml.c4.xlarge', endpoint_name=endpoint_name)
sm_model.deploy(initial_instance_count=1, instance_type='ml.m4.xlarge', endpoint_name=endpoint_name)
# Out:
# Parameter image will be renamed to image_uri in SageMaker Python SDK v2.
# Parameter image will be renamed to image_uri in SageMaker Python SDK v2.
# -------------------!

# %% [markdown]
# ## Make a request to our pipeline endpoint <a class="anchor" id="pipeline_inference_request"></a>
#
# Here we just grab the first line from the test data (you'll notice that the inference python script is very particular about the ordering of the inference request data). The ```ContentType``` field configures the first container, while the ```Accept``` field configures the last container. You can also specify each container's ```Accept``` and ```ContentType``` values using environment variables.
#
# We make our request with the payload in ```'text/csv'``` format, since that is what our script currently supports. If other formats need to be supported, this would have to be added to the ```output_fn()``` method in our entry point. Note that we set the ```Accept``` to ```application/json```, since Linear Learner does not support ```text/csv``` ```Accept```. The prediction output in this case is trying to guess the number of rings the abalone specimen would have given its other physical features; the actual number of rings is 10.

# %%
from sagemaker.predictor import json_serializer, csv_serializer, json_deserializer, RealTimePredictor
from sagemaker.content_types import CONTENT_TYPE_CSV, CONTENT_TYPE_JSON
payload = 'M, 0.44, 0.365, 0.125, 0.516, 0.2155, 0.114, 0.155'
actual_rings = 10
predictor = RealTimePredictor(
    endpoint=endpoint_name,
    sagemaker_session=sagemaker_session,
    serializer=csv_serializer,
    content_type=CONTENT_TYPE_CSV,
    accept=CONTENT_TYPE_JSON)

print(predictor.predict(payload))
# Out:
# b'{"predictions": [{"score": 9.528051376342773}]}'

# %% [markdown]
# ## Delete Endpoint <a class="anchor" id="delete_endpoint"></a>
# Once we are finished with the endpoint, we clean up the resources!

# %%
sm_client = sagemaker_session.boto_session.client('sagemaker')
sm_client.delete_endpoint(EndpointName=endpoint_name)

# %%
sm_client = sagemaker_session.boto_session.client('sagemaker')
sm_client.delete_endpoint(EndpointName=endpoint_name)
# Out:
# 'inference-pipeline-ep-2020-09-14-10-41-27'

# %%
#ll_estimator
